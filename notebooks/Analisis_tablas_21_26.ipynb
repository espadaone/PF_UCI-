# %% [markdown]
# Buscando relaciones e interpretaciones de datos tablas desde 21-26

# %%
import pandas as pd

# %%
PROCEDURES_ICD=pd.read_csv(r'C:\Users\PABLO\Henry\PROYECTO\PF\PF_UCI-\datasets\PROCEDURES_ICD.csv',sep=",")
PROCEDURES_ICD
# Out:
#      row_id  subject_id  hadm_id  seq_num  icd9_code
# 0      3994       10114   167957        1       3605
# 1      3995       10114   167957        2       3722
# 2      3996       10114   167957        3       8856
# 3      3997       10114   167957        4       9920
# 4      3998       10114   167957        5       9671
# ..      ...         ...      ...      ...        ...
# 501  230170       41976   179418        2       3893
# 502  235193       41976   155297        1       3893
# 503  235194       41976   155297        2        966
# 504  238588       41976   125013        1       3893
# 505  239961       41976   151798        1        966
#
# [506 rows x 5 columns]

# %%
D_CPT=pd.read_csv(r'C:\Users\PABLO\Henry\PROYECTO\PF\PF_UCI-\datasets\D_CPT.csv',sep=",")
D_CPT
# Out:
#      row_id  category sectionrange              sectionheader subsectionrange  \
# 0         1         1  99201-99499  Evaluation and management     99201-99216
# 1         2         1  99201-99499  Evaluation and management     99217-99220
# 2         3         1  99201-99499  Evaluation and management     99221-99239
# 3         4         1  99201-99499  Evaluation and management     99241-99255
# 4         5         1  99201-99499  Evaluation and management     99261-99263
# ..      ...       ...          ...                        ...             ...
# 129     130         2  0001F-7025F    Performance measurement     5005F-5100F
# 130     131         2  0001F-7025F    Performance measurement     6005F-6045F
# 131     132         2  0001F-7025F    Performance measurement     7010F-7025F
# 132     133         3  0016T-0207T        Emerging technology     0016T-0207T
# 133     134         3  0256T-0259T        Emerging technology     0256T-0259T
#
# ...

# %%
D_ICD_DIAGNOSES=pd.read_csv(r'C:\Users\PABLO\Henry\PROYECTO\PF\PF_UCI-\datasets\D_ICD_DIAGNOSES.csv',sep=",")
D_ICD_DIAGNOSES #Diagnosticos y abreviados
# Out:
#        row_id icd9_code               short_title  \
# 0           1     01716   Erythem nod tb-oth test
# 1           2     01720    TB periph lymph-unspec
# 2           3     01721   TB periph lymph-no exam
# 3           4     01722  TB periph lymph-exam unk
# 4           5     01723  TB periph lymph-micro dx
# ...       ...       ...                       ...
# 14562   14563     V8712  Contact/exposure benzene
# 14563   14564     V8719   Cont/exp haz aromat NEC
# 14564   14565      V872  Cont/exp hazard chem NEC
# 14565   14566     V8731     Contact/exposure mold
# 14566   14567     V8732   Contact/exp algae bloom
#
#                                               long_title
# 0      Erythema nodosum with hypersensitivity reactio...
# 1      Tuberculosis of peripheral lymph nodes, unspec...
# 2      Tuberculosis of peripheral lymph nodes, bacter...
# 3      Tuberculosis of peripheral lymph nodes, bacter...
# 4      Tuberculosis of peripheral lymph nodes, tuberc...
# ...

# %%
D_ICD_DIAGNOSES.tail()
# Out:
#        row_id icd9_code               short_title  \
# 14562   14563     V8712  Contact/exposure benzene
# 14563   14564     V8719   Cont/exp haz aromat NEC
# 14564   14565      V872  Cont/exp hazard chem NEC
# 14565   14566     V8731     Contact/exposure mold
# 14566   14567     V8732   Contact/exp algae bloom
#
#                                               long_title
# 14562   Contact with and (suspected) exposure to benzene
# 14563  Contact with and (suspected) exposure to other...
# 14564  Contact with and (suspected) exposure to other...
# 14565      Contact with and (suspected) exposure to mold
# 14566  Contact with and (suspected) exposure to algae...

# %%
D_ICD_PROCEDURES=pd.read_csv(r'C:\Users\PABLO\Henry\PROYECTO\PF\PF_UCI-\datasets\D_ICD_PROCEDURES.csv',sep=",")
D_ICD_PROCEDURES #procedimientos o tratamientos
# Out:
#       row_id  icd9_code               short_title  \
# 0          1       1423  Chorioret les xenon coag
# 1          2       1424  Chorioret les laser coag
# 2          3       1425  Chorioret les p/coag NOS
# 3          4       1426   Chorioret les radiother
# 4          5       1427  Chorioret les rad implan
# ...      ...        ...                       ...
# 3877    3878       9183                 C & s NEC
# 3878    3879       9184          Parasitology NEC
# 3879    3880       9185            Toxicology NEC
# 3880    3881       9186          Cell blk/pap NEC
# 3881    3882       9189            Micro exam NEC
#
#                                              long_title
# 0     Destruction of chorioretinal lesion by xenon a...
# 1     Destruction of chorioretinal lesion by laser p...
# 2     Destruction of chorioretinal lesion by photoco...
# 3     Destruction of chorioretinal lesion by radiati...
# 4     Destruction of chorioretinal lesion by implant...
# ...

# %%
D_ICD_PROCEDURES['short_title'].unique()
# Out:
# array(['Chorioret les xenon coag', 'Chorioret les laser coag',
#        'Chorioret les p/coag NOS', ..., 'Toxicology NEC',
#        'Cell blk/pap NEC', 'Micro exam NEC'], dtype=object)

# %%
D_ICD_PROCEDURES['long_title'].unique()
# Out:
# array(['Destruction of chorioretinal lesion by xenon arc photocoagulation',
#        'Destruction of chorioretinal lesion by laser photocoagulation',
#        'Destruction of chorioretinal lesion by photocoagulation of unspecified type',
#        ...,
#        'Microscopic examination of specimen from other site, toxicology',
#        'Microscopic examination of specimen from other site, cell block and Papanicolaou smear',
#        'Microscopic examination of specimen from other site, other microscopic examination'],
#       dtype=object)

# %%
D_ICD_PROCEDURES.tail()
# Out:
#       row_id  icd9_code       short_title  \
# 3877    3878       9183         C & s NEC
# 3878    3879       9184  Parasitology NEC
# 3879    3880       9185    Toxicology NEC
# 3880    3881       9186  Cell blk/pap NEC
# 3881    3882       9189    Micro exam NEC
#
#                                              long_title
# 3877  Microscopic examination of specimen from other...
# 3878  Microscopic examination of specimen from other...
# 3879  Microscopic examination of specimen from other...
# 3880  Microscopic examination of specimen from other...
# 3881  Microscopic examination of specimen from other...

# %%
D_ITEMS=pd.read_csv(r'C:\Users\PABLO\Henry\PROYECTO\PF\PF_UCI-\datasets\D_ITEMS.csv',sep=",")
D_ITEMS
# Out:
#        row_id  itemid                   label            abbreviation  \
# 0           1    1435      Sustained Nystamus                     NaN
# 1           2    1436    Tactile Disturbances                     NaN
# 2           3    1437                  Tremor                     NaN
# 3           4    1438     Ulnar Pulse [Right]                     NaN
# 4           5    1439     Visual Disturbances                     NaN
# ...       ...     ...                     ...                     ...
# 12482   15670  228575  Incision #5- Treatment  Incision #5- Treatment
# 12483   15671  228576  Incision #6- Treatment  Incision #6- Treatment
# 12484   15672  228577  Impaired Skin #2- Type  Impaired Skin #2- Type
# 12485   15673  228578  Impaired Skin #3- Type  Impaired Skin #3- Type
# 12486   15674  228579  Impaired Skin #4- Type  Impaired Skin #4- Type
#
#          dbsource      linksto           category unitname param_type  \
# ...

# %%
D_ITEMS['label'].unique()
# Out:
# array(['Sustained Nystamus', 'Tactile Disturbances', 'Tremor', ...,
#        'Impaired Skin #2- Type', 'Impaired Skin #3- Type',
#        'Impaired Skin #4- Type'], dtype=object)

# %%
D_ITEMS.tail()
# Out:
#        row_id  itemid                   label            abbreviation  \
# 12482   15670  228575  Incision #5- Treatment  Incision #5- Treatment
# 12483   15671  228576  Incision #6- Treatment  Incision #6- Treatment
# 12484   15672  228577  Impaired Skin #2- Type  Impaired Skin #2- Type
# 12485   15673  228578  Impaired Skin #3- Type  Impaired Skin #3- Type
# 12486   15674  228579  Impaired Skin #4- Type  Impaired Skin #4- Type
#
#          dbsource      linksto           category unitname param_type  \
# 12482  metavision  chartevents   Skin - Incisions      NaN       Text
# 12483  metavision  chartevents   Skin - Incisions      NaN       Text
# 12484  metavision  chartevents  Skin - Impairment      NaN       Text
# 12485  metavision  chartevents  Skin - Impairment      NaN       Text
# 12486  metavision  chartevents  Skin - Impairment      NaN       Text
#
#        conceptid
# 12482        NaN
# 12483        NaN
# 12484        NaN
# 12485        NaN
# 12486        NaN

# %%
D_LABITEMS=pd.read_csv(r'C:\Users\PABLO\Henry\PROYECTO\PF\PF_UCI-\datasets\D_LABITEMS.csv',sep=",")
D_LABITEMS # tipos de fluidos
# Out:
#      row_id  itemid                                label             fluid  \
# 0         1   50800                        SPECIMEN TYPE             BLOOD
# 1         2   50801           Alveolar-arterial Gradient             Blood
# 2         3   50802                          Base Excess             Blood
# 3         4   50803  Calculated Bicarbonate, Whole Blood             Blood
# 4         5   50804                 Calculated Total CO2             Blood
# ..      ...     ...                                  ...               ...
# 748     749   51551                      VOIDED SPECIMEN  OTHER BODY FLUID
# 749     750   51552                      VOIDED SPECIMEN             STOOL
# 750     751   51553                      VOIDED SPECIMEN             URINE
# 751     752   51554                      VOIDED SPECIMEN       JOINT FLUID
# 752     753   51555             SURFACTANT ALBUMIN RATIO  OTHER BODY FLUID
#
#        category loinc_code
# 0     BLOOD GAS        NaN
# ...

# %%
D_LABITEMS.tail()
# Out:
#      row_id  itemid                     label             fluid    category  \
# 748     749   51551           VOIDED SPECIMEN  OTHER BODY FLUID  HEMATOLOGY
# 749     750   51552           VOIDED SPECIMEN             STOOL   CHEMISTRY
# 750     751   51553           VOIDED SPECIMEN             URINE   CHEMISTRY
# 751     752   51554           VOIDED SPECIMEN       JOINT FLUID  HEMATOLOGY
# 752     753   51555  SURFACTANT ALBUMIN RATIO  OTHER BODY FLUID   CHEMISTRY
#
#     loinc_code
# 748        NaN
# 749        NaN
# 750        NaN
# 751        NaN
# 752        NaN
