# %%
#Importamos Librerías
import pandas as pd                             # Importamos Pandas
from datetime import datetime                   # Iportar datetime

# %%
# Diagnósticos asignados por el hospital, codificados mediante el International Statistical Classification of Diseases DNA Related Health Problems (ICD)
DIAGNOSES_ICD= pd.read_csv('PF_UCI-/datasets/DIAGNOSES_ICD.csv')

# Grupos relacionados por el diagnóstico, que el hospital utiliza para facturación
DRGCODES= pd.read_csv('PF_UCI-/datasets/DRGCODES.csv')

# Exámenes de laboratorio para pacientes del hospital y para consultas externas
LABEVENTS= pd.read_csv('PF_UCI-/datasets/LABEVENTS.csv')

# Medidas y estudios microbiológicos de la base de datos del hospital
MICROBIOLOGYEVENTS= pd.read_csv('PF_UCI-/datasets/MICROBIOLOGYEVENTS.csv')

# Órdenes de medicamentos, no siempre administradas, para un paciente
PRESCRIPTIONS= pd.read_csv('PF_UCI-/datasets/PRESCRIPTIONS.csv')

# %% [markdown]
# DIAGNOSES_ICD

# %%
# Extraemos los nombres ombres de columnas en una lista
DIAGNOSES_ICD_NAMES = list(DIAGNOSES_ICD.columns.values)
# Descripcion de columnas
DIAGNOSES_ICD_DESCRIPCIÓN = ['Identificador de fila único','ID del Paciente','Id de Admisiones','Prioridad del código. La secuencia 1 es el código principal','Clasificación Internacional de Enfermedades']
# Unimos la lista con nombres de columnas y la descripcion de cada columna
DIAGNOSES_ICD_ND= dict(zip(DIAGNOSES_ICD_NAMES,DIAGNOSES_ICD_DESCRIPCIÓN))
# Creamos el df
DIAGNOSES_ICD_columnas = pd.DataFrame([[key, DIAGNOSES_ICD_ND[key]] for key in DIAGNOSES_ICD_ND.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
DIAGNOSES_ICD_dtype = ['INT','INT','INT','INT','VARCHAR(10)']
# Agregamos el tipo de dato
DIAGNOSES_ICD_columnas['Dtype'] = DIAGNOSES_ICD_dtype
# Agregamos nombre de columna
DIAGNOSES_ICD_columnas['tabla'] = 'DIAGNOSES_ICD'
# Agregamos número de columna
DIAGNOSES_ICD_columnas['n tabla'] = 16
#Print el resultado
DIAGNOSES_ICD_columnas
# Out:
#          Name                                        Descripcion        Dtype  \
# 0      row_id                        Identificador de fila único          INT
# 1  subject_id                                    ID del Paciente          INT
# 2     hadm_id                                   Id de Admisiones          INT
# 3     seq_num  Prioridad del código. La secuencia 1 es el cód...          INT
# 4   icd9_code        Clasificación Internacional de Enfermedades  VARCHAR(10)
#
#            tabla  n tabla
# 0  DIAGNOSES_ICD       16
# 1  DIAGNOSES_ICD       16
# 2  DIAGNOSES_ICD       16
# 3  DIAGNOSES_ICD       16
# 4  DIAGNOSES_ICD       16

# %% [markdown]
# DRGCODES

# %%
# Extraemos los nombres ombres de columnas en una lista
DRGCODES_NAMES = list(DRGCODES.columns.values)
# Descripcion de columnas
DRGCODES_DESCRIPCIÓN = ['Identificador de la Fila',
                        'ID del Paciente',
                        'Id de Admisiones',
                        'Tipo de grupo relacionado con el diagnóstico',
                        'Código de grupo relacionado con el diagnóstico',
                        'Descripción del DRG',
                        'Gravedad relativa',
                        'Mortalidad relativa']
# Unimos la lista con nombres de columnas y la descripcion de cada columna
DRGCODES_ND= dict(zip(DRGCODES_NAMES,DRGCODES_DESCRIPCIÓN))
# Creamos el df
DRGCODES_columnas = pd.DataFrame([[key, DRGCODES_ND[key]] for key in DRGCODES_ND.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
DRGCODES_dtype = ['INT','INT','INT','VARCHAR(20)','VARCHAR(20)','VARCHAR(300)','SMALLINT','SMALLINT']
# Agregamos el tipo de dato
DRGCODES_columnas['Dtype'] = DRGCODES_dtype
# Agregamos nombre de columna
DRGCODES_columnas['tabla'] = 'DRGCODES'
# Agregamos número de columna
DRGCODES_columnas['n tabla'] = 17
#Print el resultado
DRGCODES_columnas
# Out:
#             Name                                     Descripcion  \
# 0         row_id                        Identificador de la Fila
# 1     subject_id                                 ID del Paciente
# 2        hadm_id                                Id de Admisiones
# 3       drg_type    Tipo de grupo relacionado con el diagnóstico
# 4       drg_code  Código de grupo relacionado con el diagnóstico
# 5    description                             Descripción del DRG
# 6   drg_severity                               Gravedad relativa
# 7  drg_mortality                             Mortalidad relativa
#
#           Dtype     tabla  n tabla
# 0           INT  DRGCODES       17
# 1           INT  DRGCODES       17
# 2           INT  DRGCODES       17
# 3   VARCHAR(20)  DRGCODES       17
# 4   VARCHAR(20)  DRGCODES       17
# 5  VARCHAR(300)  DRGCODES       17
# 6      SMALLINT  DRGCODES       17
# 7      SMALLINT  DRGCODES       17

# %% [markdown]
# LABEVENTS

# %%
# Extraemos los nombres ombres de columnas en una lista
LABEVENTS_NAMES = list(LABEVENTS.columns.values)
# Descripcion de columnas
LABEVENTS_DESCRIPCIÓN = ['Identificador de fila único',
                         'ID del Paciente',
                         'Id de Admisiones',
                         'Referencia a la tabla D_LABITEMS',
                         'Momento en que ocurrió el evento',
                         'Valor del evento en formato texto',
                         'Valor del evento como un número',
                         'Unidad de medida',
                         'Estado del valor de la prueba de laboratorio (NULL = normal)']
# Unimos la lista con nombres de columnas y la descripcion de cada columna
LABEVENTS_ND= dict(zip(LABEVENTS_NAMES,LABEVENTS_DESCRIPCIÓN))
# Creamos el df
LABEVENTS_columnas = pd.DataFrame([[key, LABEVENTS_ND[key]] for key in LABEVENTS_ND.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
LABEVENTS_dtype = ['INT','INT','INT','INT','TIMESTAMP(0)','VARCHAR(200)','DOUBLE PRECISION','VARCHAR(20)','VARCHAR(20)']
# Agregamos el tipo de dato
LABEVENTS_columnas['Dtype'] = LABEVENTS_dtype
# Agregamos nombre de columna
LABEVENTS_columnas['tabla'] = 'DIAGNOSES_ICD'
# Agregamos número de columna
LABEVENTS_columnas['n tabla'] = 18
#Print el resultado
LABEVENTS_columnas
# Out:
#          Name                                        Descripcion  \
# 0      row_id                        Identificador de fila único
# 1  subject_id                                    ID del Paciente
# 2     hadm_id                                   Id de Admisiones
# 3      itemid                   Referencia a la tabla D_LABITEMS
# 4   charttime                   Momento en que ocurrió el evento
# 5       value                  Valor del evento en formato texto
# 6    valuenum                    Valor del evento como un número
# 7    valueuom                                   Unidad de medida
# 8        flag  Estado del valor de la prueba de laboratorio (...
#
#               Dtype          tabla  n tabla
# 0               INT  DIAGNOSES_ICD       18
# 1               INT  DIAGNOSES_ICD       18
# 2               INT  DIAGNOSES_ICD       18
# 3               INT  DIAGNOSES_ICD       18
# 4      TIMESTAMP(0)  DIAGNOSES_ICD       18
# 5      VARCHAR(200)  DIAGNOSES_ICD       18
# 6  DOUBLE PRECISION  DIAGNOSES_ICD       18
# 7       VARCHAR(20)  DIAGNOSES_ICD       18
# 8       VARCHAR(20)  DIAGNOSES_ICD       18

# %% [markdown]
# MICROBIOLOGYEVENTS

# %%
# Extraemos los nombres ombres de columnas en una lista
MICROBIOLOGYEVENTS_NAMES = list(MICROBIOLOGYEVENTS.columns.values)
# Descripcion de columnas
MICROBIOLOGYEVENTS_DESCRIPCIÓN = ['Identificador de fila único',
                                  'ID del Paciente',
                                  'Id de Admisiones',
                                  'Fecha en que ocurrió el evento',
                                  'Hora en que ocurrió el evento',
                                  'Identifica el espécimen',
                                  'Descripción del espécimen',
                                  'Identifica el organismo',
                                  'Nombre del organismo',
                                  'Número aislado asociado a la prueba',
                                  'Identifica el anticuerpo',
                                  'Nombre del anticuerpo utilizado',
                                  'La cantidad de dilución probada y la comparación que se hizo',
                                  'El componente de comparación de DILUTION_TEXT',
                                  'El valor del componente DILUTION_TEXT',
                                  'Interpretación de la prueba']
# Unimos la lista con nombres de columnas y la descripcion de cada columna
MICROBIOLOGYEVENTS_ND= dict(zip(MICROBIOLOGYEVENTS_NAMES,MICROBIOLOGYEVENTS_DESCRIPCIÓN))
# Creamos el df
MICROBIOLOGYEVENTS_columnas = pd.DataFrame([[key, MICROBIOLOGYEVENTS_ND[key]] for key in MICROBIOLOGYEVENTS_ND.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
MICROBIOLOGYEVENTS_dtype = ['INT','INT','INT','TIMESTAMP(0)','TIMESTAMP(0)','INT','VARCHAR(100)',
                            'INT','VARCHAR(100)','SMALLINT','INT','VARCHAR(30)','VARCHAR(10)',
                            'VARCHAR(20)','DOUBLE PRECISION','VARCHAR(5)']
# Agregamos el tipo de dato
MICROBIOLOGYEVENTS_columnas['Dtype'] = MICROBIOLOGYEVENTS_dtype
# Agregamos nombre de columna
MICROBIOLOGYEVENTS_columnas['tabla'] = 'MICROBIOLOGYEVENTS'
# Agregamos número de columna
MICROBIOLOGYEVENTS_columnas['n tabla'] = 19
#Print el resultado
MICROBIOLOGYEVENTS_columnas
# Out:
#                    Name                                        Descripcion  \
# 0                row_id                        Identificador de fila único
# 1            subject_id                                    ID del Paciente
# 2               hadm_id                                   Id de Admisiones
# 3             chartdate                     Fecha en que ocurrió el evento
# 4             charttime                      Hora en que ocurrió el evento
# 5           spec_itemid                            Identifica el espécimen
# 6        spec_type_desc                          Descripción del espécimen
# 7            org_itemid                            Identifica el organismo
# 8              org_name                               Nombre del organismo
# 9           isolate_num                Número aislado asociado a la prueba
# 10            ab_itemid                           Identifica el anticuerpo
# 11              ab_name                    Nombre del anticuerpo utilizado
# 12        dilution_text  La cantidad de dilución probada y la comparaci...
# 13  dilution_comparison      El componente de comparación de DILUTION_TEXT
# 14       dilution_value              El valor del componente DILUTION_TEXT
# 15       interpretation                        Interpretación de la prueba
#
#                Dtype               tabla  n tabla
# 0                INT  MICROBIOLOGYEVENTS       19
# 1                INT  MICROBIOLOGYEVENTS       19
# 2                INT  MICROBIOLOGYEVENTS       19
# 3       TIMESTAMP(0)  MICROBIOLOGYEVENTS       19
# 4       TIMESTAMP(0)  MICROBIOLOGYEVENTS       19
# 5                INT  MICROBIOLOGYEVENTS       19
# 6       VARCHAR(100)  MICROBIOLOGYEVENTS       19
# 7                INT  MICROBIOLOGYEVENTS       19
# 8       VARCHAR(100)  MICROBIOLOGYEVENTS       19
# 9           SMALLINT  MICROBIOLOGYEVENTS       19
# 10               INT  MICROBIOLOGYEVENTS       19
# 11       VARCHAR(30)  MICROBIOLOGYEVENTS       19
# 12       VARCHAR(10)  MICROBIOLOGYEVENTS       19
# 13       VARCHAR(20)  MICROBIOLOGYEVENTS       19
# 14  DOUBLE PRECISION  MICROBIOLOGYEVENTS       19
# 15        VARCHAR(5)  MICROBIOLOGYEVENTS       19

# %% [markdown]
# PRESCRIPTIONS

# %%
# Extraemos los nombres ombres de columnas en una lista
PRESCRIPTIONS_NAMES = list(PRESCRIPTIONS.columns.values)
# Descripcion de columnas
PRESCRIPTIONS_DESCRIPCIÓN = ['Identificador de fila único',
                             'ID del Paciente',
                             'ID del Admisiones',
                             'Referencia a ICUSTAYS',
                             'Fecha en que comenzó la prescripción',
                             'Fecha en que terminó la prescripción',
                             'tipo de droga',
                             'nombre de la droga',
                             'Nombre del medicamento en la interfaz de entrada de pedidos del proveedor',
                             'nombre genérico de la droga',
                             'Código de medicamento del formulario',
                             'Número de secuencia genérico',
                             'Código Nacional de Drogas',
                             'Fuerza de la droga (producto)',
                             'Dosis del fármaco prescrito',
                             'Unidad de medida asociada a la dosis',
                             'Cantidad de la fórmula dispensada',
                             'Unidad de medida asociada a la formulación',
                             'Vía de administración']
# Unimos la lista con nombres de columnas y la descripcion de cada columna
PRESCRIPTIONS_ND= dict(zip(PRESCRIPTIONS_NAMES,PRESCRIPTIONS_DESCRIPCIÓN))
# Creamos el df
PRESCRIPTIONS_columnas = pd.DataFrame([[key, PRESCRIPTIONS_ND[key]] for key in PRESCRIPTIONS_ND.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
PRESCRIPTIONS_dtype = ['INT','INT','INT','INT','TIMESTAMP(0)','TIMESTAMP(0)','VARCHAR(100)',
                       'VARCHAR(100)','VARCHAR(100)','VARCHAR(100)','VARCHAR(120)','VARCHAR(200)',
                       'VARCHAR(120)','VARCHAR(120)','VARCHAR(120)','VARCHAR(120)','VARCHAR(120)',
                       'VARCHAR(120)','VARCHAR(120)']
# Agregamos el tipo de dato
PRESCRIPTIONS_columnas['Dtype'] = PRESCRIPTIONS_dtype
# Agregamos nombre de columna
PRESCRIPTIONS_columnas['tabla'] = 'PRESCRIPTIONS'
# Agregamos número de columna
PRESCRIPTIONS_columnas['n tabla'] = 20
#Print el resultado
PRESCRIPTIONS_columnas
# Out:
#                  Name                                        Descripcion  \
# 0              row_id                        Identificador de fila único
# 1          subject_id                                    ID del Paciente
# 2             hadm_id                                  ID del Admisiones
# 3          icustay_id                              Referencia a ICUSTAYS
# 4           startdate               Fecha en que comenzó la prescripción
# 5             enddate               Fecha en que terminó la prescripción
# 6           drug_type                                      tipo de droga
# 7                drug                                 nombre de la droga
# 8       drug_name_poe  Nombre del medicamento en la interfaz de entra...
# 9   drug_name_generic                        nombre genérico de la droga
# 10  formulary_drug_cd               Código de medicamento del formulario
# 11                gsn                       Número de secuencia genérico
# 12                ndc                          Código Nacional de Drogas
# 13      prod_strength                      Fuerza de la droga (producto)
# 14        dose_val_rx                        Dosis del fármaco prescrito
# 15       dose_unit_rx               Unidad de medida asociada a la dosis
# 16      form_val_disp                  Cantidad de la fórmula dispensada
# 17     form_unit_disp         Unidad de medida asociada a la formulación
# 18              route                              Vía de administración
#
#            Dtype          tabla  n tabla
# 0            INT  PRESCRIPTIONS       20
# 1            INT  PRESCRIPTIONS       20
# 2            INT  PRESCRIPTIONS       20
# 3            INT  PRESCRIPTIONS       20
# 4   TIMESTAMP(0)  PRESCRIPTIONS       20
# 5   TIMESTAMP(0)  PRESCRIPTIONS       20
# 6   VARCHAR(100)  PRESCRIPTIONS       20
# 7   VARCHAR(100)  PRESCRIPTIONS       20
# 8   VARCHAR(100)  PRESCRIPTIONS       20
# 9   VARCHAR(100)  PRESCRIPTIONS       20
# 10  VARCHAR(120)  PRESCRIPTIONS       20
# 11  VARCHAR(200)  PRESCRIPTIONS       20
# 12  VARCHAR(120)  PRESCRIPTIONS       20
# 13  VARCHAR(120)  PRESCRIPTIONS       20
# 14  VARCHAR(120)  PRESCRIPTIONS       20
# 15  VARCHAR(120)  PRESCRIPTIONS       20
# 16  VARCHAR(120)  PRESCRIPTIONS       20
# 17  VARCHAR(120)  PRESCRIPTIONS       20
# 18  VARCHAR(120)  PRESCRIPTIONS       20

# %% [markdown]
# # CONTACT

# %%
T_16_20 = pd.merge(DIAGNOSES_ICD, DRGCODES,LABEVENTS,MICROBIOLOGYEVENTS,PRESCRIPTIONS,on="Index")
T_16_20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\Desktop\Curso_Data_Science\PG\DIC-tablas_16_20.ipynb Celda 14 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Curso_Data_Science/PG/DIC-tablas_16_20.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> T_16_20 = pd.merge(DIAGNOSES_ICD, DRGCODES,LABEVENTS,MICROBIOLOGYEVENTS,PRESCRIPTIONS,on="Index")
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Curso_Data_Science/PG/DIC-tablas_16_20.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> T_16_20
#
# TypeError: merge() got multiple values for argument 'on'
