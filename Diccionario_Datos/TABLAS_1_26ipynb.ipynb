# %%
# !git clone https://github.com/espadaone/PF_UCI-.git
# Out:
# Cloning into 'PF_UCI-'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 174 (delta 40), reused 51 (delta 14), pack-reused 81
# Receiving objects: 100% (174/174), 64.86 MiB | 22.11 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
import pandas as pd

tabla_1_5 = pd.read_csv('/content/PF_UCI-/Diccionario_Datos/Tablas_1_5.csv')
tabla_6_10 = pd.read_csv('/content/PF_UCI-/Diccionario_Datos/tablas_6a10.csv')
tabla_11_15 = pd.read_csv('/content/PF_UCI-/Diccionario_Datos/Diccionario_tablas_11_15.csv')
tabla_16_20 = pd.read_csv('/content/PF_UCI-/Diccionario_Datos/tablas_16_20.csv')
tabla_21_26 = pd.read_csv('/content/PF_UCI-/Diccionario_Datos/UnionTablas21_26.csv')

# %%
# debemos quitar Unnamed: 0
tabla_1_5.head(1)
# Out:
#    Unnamed: 0    Name                             Descripcion Dtype  \
# 0           0  row_id  (Obsoleto) Identificador de fila único   int
#
#         tabla  n tabla
# 0  admissions        1

# %%
tabla_6_10.head(1)
# Out:
#      Name Descripcion Dtype      tabla  n tabla
# 0  row_id  id de fila   int  transfers        6

# %%
# "Tabla "deberia ser "tabla"
tabla_11_15.head(1)
# Out:
#      Name             Descripcion  Dtype           Tabla  n tabla
# 0  row_id  Identificador de linea  int64  INPUTEVENTS_MV       11

# %%
tabla_16_20.head(1)
# Out:
#      Name                  Descripcion Dtype          tabla  n tabla
# 0  row_id  Identificador de fila único   INT  DIAGNOSES_ICD       16

# %%
# falta el numero de tabla
# hay que quitar unnamed: 0
tabla_21_26.head(1)
# Out:
#    Unnamed: 0    Name            Descripcion Dtype           tabla
# 0           0  row_id  identificador de fila   int  PROCEDURES_ICD

# %%
tabla_1_5 = tabla_1_5[['Name','Descripcion','Dtype','tabla','n tabla']]

# %%
tabla_1_5.head(1)
# Out:
#      Name                             Descripcion Dtype       tabla  n tabla
# 0  row_id  (Obsoleto) Identificador de fila único   int  admissions        1

# %%
tabla_11_15.rename(columns = {'Tabla':'tabla'}, inplace = True)

# %%
# hay dos tablas con el mismo nombre, las ultimas 2
tabla_21_26
# Out:
#     Unnamed: 0                 Name  \
# 0            0               row_id
# 1            1           subject_id
# 2            2              hadm_id
# 3            3              seq_num
# 4            4            icd9_code
# 5            0               row_id
# 6            1             category
# 7            2         sectionrange
# 8            3        sectionheader
# 9            4      subsectionrange
# 10           5     subsectionheader
# 11           6           codesuffix
# 12           7  mincodeinsubsection
# 13           8  maxcodeinsubsection
# 14           0               row_id
# 15           1            icd9_code
# 16           2          short_title
# 17           3           long_title
# 18           0               row_id
# 19           1            icd9_code
# 20           2          short_title
# 21           3           long_title
# 22           0               row_id
# 23           1               itemid
# 24           2                label
# ...

# %%
# Corregimos nombre de tablas
tabla_21_26['tabla'].loc[32] = 'D_LABITEMS'
tabla_21_26['tabla'].loc[33] = 'D_LABITEMS'
tabla_21_26['tabla'].loc[34] = 'D_LABITEMS'
tabla_21_26['tabla'].loc[35] = 'D_LABITEMS'
tabla_21_26['tabla'].loc[36] = 'D_LABITEMS'
tabla_21_26['tabla'].loc[37] = 'D_LABITEMS'
# Agregamos numero de tablas
tabla_21_26['n tabla'] = [21,21,21,21,21,22,22,22,22,22,22,22,22,22,23,23,23,23,24,24,24,24,25,25,25,25,25,25,25,25,25,25,26,26,26,26,26,26]
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# eliminamos el 2do indice que no nos sirve
tabla_21_26 = tabla_21_26[['Name','Descripcion','Dtype','tabla','n tabla']]
tabla_21_26.head(1)
# Out:
#      Name            Descripcion Dtype           tabla  n tabla
# 0  row_id  identificador de fila   int  PROCEDURES_ICD       21

# %%
tablas_1_26 = pd.concat([tabla_1_5,tabla_6_10,tabla_11_15,tabla_16_20,tabla_21_26])
tablas_1_26
# Out:
#           Name                                        Descripcion Dtype  \
# 0       row_id             (Obsoleto) Identificador de fila único   int
# 1   subject_id              PACIENTES DE REFERENCIAS (SUBJECT_ID)   int
# 2      hadm_id  Identificador único para cada estancia hospita...   int
# 3    admittime                                    Hora de ingreso  Date
# 4    dischtime                                       Hora de alta  Date
# ..         ...                                                ...   ...
# 33      itemid                              Clasificación de item   int
# 34       label                                   Nombre del item      O
# 35       fluid                                     Tipo de fluido     O
# 36    category                                          categoria     O
# 37  loinc_code   Identificador logico por nombre y codigo de item     O
#
#          tabla  n tabla
# 0   admissions        1
# 1   admissions        1
# 2   admissions        1
# ...

# %%
tablas_1_26.head(40)
# Out:
#                     Name                                        Descripcion  \
# 0                 row_id             (Obsoleto) Identificador de fila único
# 1             subject_id              PACIENTES DE REFERENCIAS (SUBJECT_ID)
# 2                hadm_id  Identificador único para cada estancia hospita...
# 3              admittime                                    Hora de ingreso
# 4              dischtime                                       Hora de alta
# 5              deathtime                                  Hora de la muerte
# 6         admission_type  Tipo de admisión [ejemplo: emergencia o electiva]
# 7     admission_location                                  Lugar de admisión
# 8     discharge_location                                      Lugar de alta
# 9              insurance                                     Tipo de seguro
# 10              language                                             Idioma
# ...

# %%
tablas_1_26.tail(40)
# Out:
#                    Name                                        Descripcion  \
# 55       form_unit_disp         Unidad de medida asociada a la formulación
# 56                route                              Vía de administración
# 0                row_id                              identificador de fila
# 1            subject_id                                     id de paciente
# 2               hadm_id                                     id de admision
# 3               seq_num             numero de procedimiento ocurrido antes
# 4             icd9_code  clasificación para describir enfermedades, les...
# 5                row_id                              identificador de fila
# 6              category                                          categoria
# 7          sectionrange                                Rango de la seccion
# 8         sectionheader                                   seccion cabecera
# ...

# %%
tablas_1_26.reset_index(inplace = True)
tablas_1_26 = tablas_1_26[['Name','Descripcion','Dtype','tabla','n tabla']]
tablas_1_26
# Out:
#            Name                                        Descripcion Dtype  \
# 0        row_id             (Obsoleto) Identificador de fila único   int
# 1    subject_id              PACIENTES DE REFERENCIAS (SUBJECT_ID)   int
# 2       hadm_id  Identificador único para cada estancia hospita...   int
# 3     admittime                                    Hora de ingreso  Date
# 4     dischtime                                       Hora de alta  Date
# ..          ...                                                ...   ...
# 319      itemid                              Clasificación de item   int
# 320       label                                   Nombre del item      O
# 321       fluid                                     Tipo de fluido     O
# 322    category                                          categoria     O
# 323  loinc_code   Identificador logico por nombre y codigo de item     O
#
#           tabla  n tabla
# 0    admissions        1
# 1    admissions        1
# ...

# %%
tablas_1_26.to_csv('TABLAS_1_26.csv')
