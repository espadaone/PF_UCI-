# %%
import pandas as pd

# %% [markdown]
# tabla 21

# %%
PROCEDURES_ICD=pd.read_csv(r'https://raw.githubusercontent.com/espadaone/PF_UCI-/main/datasets/PROCEDURES_ICD.csv',sep=",")
PROCEDURES_ICD #Diagnosticos y abreviados
# Out:
#      row_id  subject_id  hadm_id  seq_num  icd9_code
# 0      3994       10114   167957        1       3605
# 1      3995       10114   167957        2       3722
# 2      3996       10114   167957        3       8856
# 3      3997       10114   167957        4       9920
# 4      3998       10114   167957        5       9671
# ..      ...         ...      ...      ...        ...
# 501  230170       41976   179418        2       3893
# 502  235193       41976   155297        1       3893
# 503  235194       41976   155297        2        966
# 504  238588       41976   125013        1       3893
# 505  239961       41976   151798        1        966
#
# [506 rows x 5 columns]

# %%
PROCEDURES_ICD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   row_id      506 non-null    int64
#  1   subject_id  506 non-null    int64
#  2   hadm_id     506 non-null    int64
#  3   seq_num     506 non-null    int64
#  4   icd9_code   506 non-null    int64
# dtypes: int64(5)
# memory usage: 19.9 KB

# %%
PROCEDURES_ICD_names = list(PROCEDURES_ICD.columns.values)
PROCEDURES_ICD_names
# Out:
# ['row_id', 'subject_id', 'hadm_id', 'seq_num', 'icd9_code']

# %%
# Descripcion de columnas
PROCEDURES_ICD_descripcion = ['identificador de fila','id de paciente','id de admision','numero de procedimiento ocurrido antes','clasificación para describir enfermedades, lesiones y afecciones médicas ']

# %%
# Unimos la lista con nombres de columnas y la descripcion de cada columna
PROCEDURES_ICD_completo= dict(zip(PROCEDURES_ICD_names,PROCEDURES_ICD_descripcion))
# Creamos el df
PROCEDURES_ICD_columnas = pd.DataFrame([[key, PROCEDURES_ICD_completo[key]] for key in PROCEDURES_ICD_completo.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
PROCEDURES_ICD_dtype = ['int','int','int','int','O']
# Agregamos el tipo de dato
PROCEDURES_ICD_columnas['Dtype'] = PROCEDURES_ICD_dtype
# Agregamos nombre de columna
PROCEDURES_ICD_columnas['tabla'] = 'PROCEDURES_ICD'

# %%
PROCEDURES_ICD_columnas
# Out:
#          Name                                        Descripcion Dtype  \
# 0      row_id                              identificador de fila   int
# 1  subject_id                                     id de paciente   int
# 2     hadm_id                                     id de admision   int
# 3     seq_num             numero de procedimiento ocurrido antes   int
# 4   icd9_code  clasificación para describir enfermedades, les...     O
#
#             tabla
# 0  PROCEDURES_ICD
# 1  PROCEDURES_ICD
# 2  PROCEDURES_ICD
# 3  PROCEDURES_ICD
# 4  PROCEDURES_ICD

# %% [markdown]
# tabla-22

# %%
D_CPT=pd.read_csv(r'https://raw.githubusercontent.com/espadaone/PF_UCI-/main/datasets/D_CPT.csv',sep=",")
D_CPT #Diagnosticos y abreviados
# Out:
#      row_id  category sectionrange              sectionheader subsectionrange  \
# 0         1         1  99201-99499  Evaluation and management     99201-99216
# 1         2         1  99201-99499  Evaluation and management     99217-99220
# 2         3         1  99201-99499  Evaluation and management     99221-99239
# 3         4         1  99201-99499  Evaluation and management     99241-99255
# 4         5         1  99201-99499  Evaluation and management     99261-99263
# ..      ...       ...          ...                        ...             ...
# 129     130         2  0001F-7025F    Performance measurement     5005F-5100F
# 130     131         2  0001F-7025F    Performance measurement     6005F-6045F
# 131     132         2  0001F-7025F    Performance measurement     7010F-7025F
# 132     133         3  0016T-0207T        Emerging technology     0016T-0207T
# 133     134         3  0256T-0259T        Emerging technology     0256T-0259T
#
# ...

# %%
D_CPT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   row_id               134 non-null    int64
#  1   category             134 non-null    int64
#  2   sectionrange         134 non-null    object
#  3   sectionheader        134 non-null    object
#  4   subsectionrange      134 non-null    object
#  5   subsectionheader     134 non-null    object
#  6   codesuffix           11 non-null     object
#  7   mincodeinsubsection  134 non-null    int64
#  8   maxcodeinsubsection  134 non-null    int64
# dtypes: int64(4), object(5)
# memory usage: 9.5+ KB

# %%
D_CPT_names = list(D_CPT.columns.values)
D_CPT_names
# Out:
# ['row_id',
#  'category',
#  'sectionrange',
#  'sectionheader',
#  'subsectionrange',
#  'subsectionheader',
#  'codesuffix',
#  'mincodeinsubsection',
#  'maxcodeinsubsection']

# %%
D_CPT_descripcion = ['identificador de fila','categoria','Rango de la seccion','seccion cabecera','Rango de la subseccion','cabecera de la subseccion','Elem. de Texto de terminologia procesal','codigo minimo dentro de la subseccion','codigo maximo dentro de la subseccion']

# %%
# Unimos la lista con nombres de columnas y la descripcion de cada columna
D_CPT_completo= dict(zip(D_CPT_names,D_CPT_descripcion))
# Creamos el df
D_CPT_columnas = pd.DataFrame([[key, D_CPT_completo[key]] for key in D_CPT_completo.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
D_CPT_dtype = ['int','int','O','O','O','O','O','int','int']
# Agregamos el tipo de dato
D_CPT_columnas['Dtype'] = D_CPT_dtype
# Agregamos nombre de columna
D_CPT_columnas['tabla'] = 'D_CPT'

# %%
D_CPT_columnas
# Out:
#                   Name                              Descripcion Dtype  tabla
# 0               row_id                    identificador de fila   int  D_CPT
# 1             category                                categoria   int  D_CPT
# 2         sectionrange                      Rango de la seccion     O  D_CPT
# 3        sectionheader                         seccion cabecera     O  D_CPT
# 4      subsectionrange                   Rango de la subseccion     O  D_CPT
# 5     subsectionheader                cabecera de la subseccion     O  D_CPT
# 6           codesuffix  Elem. de Texto de terminologia procesal     O  D_CPT
# 7  mincodeinsubsection    codigo minimo dentro de la subseccion   int  D_CPT
# 8  maxcodeinsubsection    codigo maximo dentro de la subseccion   int  D_CPT

# %% [markdown]
# tabla-23

# %%
D_ICD_DIAGNOSES=pd.read_csv(r'https://raw.githubusercontent.com/espadaone/PF_UCI-/main/datasets/D_ICD_DIAGNOSES.csv',sep=",")
D_ICD_DIAGNOSES #Diagnosticos y abreviados
# Out:
#        row_id icd9_code               short_title  \
# 0           1     01716   Erythem nod tb-oth test
# 1           2     01720    TB periph lymph-unspec
# 2           3     01721   TB periph lymph-no exam
# 3           4     01722  TB periph lymph-exam unk
# 4           5     01723  TB periph lymph-micro dx
# ...       ...       ...                       ...
# 14562   14563     V8712  Contact/exposure benzene
# 14563   14564     V8719   Cont/exp haz aromat NEC
# 14564   14565      V872  Cont/exp hazard chem NEC
# 14565   14566     V8731     Contact/exposure mold
# 14566   14567     V8732   Contact/exp algae bloom
#
#                                               long_title
# 0      Erythema nodosum with hypersensitivity reactio...
# 1      Tuberculosis of peripheral lymph nodes, unspec...
# 2      Tuberculosis of peripheral lymph nodes, bacter...
# 3      Tuberculosis of peripheral lymph nodes, bacter...
# 4      Tuberculosis of peripheral lymph nodes, tuberc...
# ...

# %%
D_ICD_DIAGNOSES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14567 entries, 0 to 14566
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   row_id       14567 non-null  int64
#  1   icd9_code    14567 non-null  object
#  2   short_title  14567 non-null  object
#  3   long_title   14567 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 455.3+ KB

# %%
D_ICD_DIAGNOSES_names = list(D_ICD_DIAGNOSES.columns.values)
D_ICD_DIAGNOSES_names
# Out:
# ['row_id', 'icd9_code', 'short_title', 'long_title']

# %%
# Descripcion de columnas
D_ICD_DIAGNOSES_descripcion = ['identificador de fila','clasificación para describir enfermedades, lesiones y afecciones médicas ','titulo corto de enfermedad o lesion etc','titulo largo de enfermedad o lesion.etc']

# %%
# Unimos la lista con nombres de columnas y la descripcion de cada columna
D_ICD_DIAGNOSES_completo= dict(zip(D_ICD_DIAGNOSES_names,D_ICD_DIAGNOSES_descripcion))
# Creamos el df
D_ICD_DIAGNOSES_columnas = pd.DataFrame([[key, D_ICD_DIAGNOSES_completo[key]] for key in D_ICD_DIAGNOSES_completo.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
D_ICD_DIAGNOSES_dtype = ['int','int','O','O']
# Agregamos el tipo de dato
D_ICD_DIAGNOSES_columnas['Dtype'] = D_ICD_DIAGNOSES_dtype
# Agregamos nombre de columna
D_ICD_DIAGNOSES_columnas['tabla'] = 'D_ICD_DIAGNOSES'

# %%
D_ICD_DIAGNOSES_columnas
# Out:
#           Name                                        Descripcion Dtype  \
# 0       row_id                              identificador de fila   int
# 1    icd9_code  clasificación para describir enfermedades, les...   int
# 2  short_title            titulo corto de enfermedad o lesion etc     O
# 3   long_title            titulo largo de enfermedad o lesion.etc     O
#
#              tabla
# 0  D_ICD_DIAGNOSES
# 1  D_ICD_DIAGNOSES
# 2  D_ICD_DIAGNOSES
# 3  D_ICD_DIAGNOSES

# %% [markdown]
# tabla 24

# %%
D_ICD_PROCEDURES=pd.read_csv(r'https://raw.githubusercontent.com/espadaone/PF_UCI-/main/datasets/D_ICD_DIAGNOSES.csv',sep=",")
D_ICD_PROCEDURES #Diagnosticos y abreviados
# Out:
#        row_id icd9_code               short_title  \
# 0           1     01716   Erythem nod tb-oth test
# 1           2     01720    TB periph lymph-unspec
# 2           3     01721   TB periph lymph-no exam
# 3           4     01722  TB periph lymph-exam unk
# 4           5     01723  TB periph lymph-micro dx
# ...       ...       ...                       ...
# 14562   14563     V8712  Contact/exposure benzene
# 14563   14564     V8719   Cont/exp haz aromat NEC
# 14564   14565      V872  Cont/exp hazard chem NEC
# 14565   14566     V8731     Contact/exposure mold
# 14566   14567     V8732   Contact/exp algae bloom
#
#                                               long_title
# 0      Erythema nodosum with hypersensitivity reactio...
# 1      Tuberculosis of peripheral lymph nodes, unspec...
# 2      Tuberculosis of peripheral lymph nodes, bacter...
# 3      Tuberculosis of peripheral lymph nodes, bacter...
# 4      Tuberculosis of peripheral lymph nodes, tuberc...
# ...

# %%
D_ICD_PROCEDURES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14567 entries, 0 to 14566
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   row_id       14567 non-null  int64
#  1   icd9_code    14567 non-null  object
#  2   short_title  14567 non-null  object
#  3   long_title   14567 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 455.3+ KB

# %%
D_ICD_PROCEDURES_names = list(D_ICD_PROCEDURES.columns.values)
D_ICD_PROCEDURES_names
# Out:
# ['row_id', 'icd9_code', 'short_title', 'long_title']

# %%
D_ICD_PROCEDURES_descripcion = ['identificador de fila','clasificación para describir enfermedades, lesiones y afecciones médicas ','titulo corto de enfermedad o lesion etc','titulo largo de enfermedad o lesion.etc']

# %%
# Unimos la lista con nombres de columnas y la descripcion de cada columna
D_ICD_PROCEDURES_completo= dict(zip(D_ICD_PROCEDURES_names,D_ICD_PROCEDURES_descripcion))
# Creamos el df
D_ICD_PROCEDURES_columnas = pd.DataFrame([[key, D_ICD_PROCEDURES_completo[key]] for key in D_ICD_PROCEDURES_completo.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
D_ICD_PROCEDURES_dtype = ['int','int','O','O']
# Agregamos el tipo de dato
D_ICD_PROCEDURES_columnas['Dtype'] = D_ICD_PROCEDURES_dtype
# Agregamos nombre de columna
D_ICD_PROCEDURES_columnas['tabla'] = 'D_ICD_PROCEDURES'

# %%
D_ICD_PROCEDURES_columnas
# Out:
#           Name                                        Descripcion Dtype  \
# 0       row_id                              identificador de fila   int
# 1    icd9_code  clasificación para describir enfermedades, les...   int
# 2  short_title            titulo corto de enfermedad o lesion etc     O
# 3   long_title            titulo largo de enfermedad o lesion.etc     O
#
#               tabla
# 0  D_ICD_PROCEDURES
# 1  D_ICD_PROCEDURES
# 2  D_ICD_PROCEDURES
# 3  D_ICD_PROCEDURES

# %% [markdown]
# tabla 25

# %%
D_ITEMS=pd.read_csv(r'https://raw.githubusercontent.com/espadaone/PF_UCI-/main/datasets/D_ITEMS.csv',sep=",")
D_ITEMS #Diagnosticos y abreviados
# Out:
#        row_id  itemid                   label            abbreviation  \
# 0           1    1435      Sustained Nystamus                     NaN
# 1           2    1436    Tactile Disturbances                     NaN
# 2           3    1437                  Tremor                     NaN
# 3           4    1438     Ulnar Pulse [Right]                     NaN
# 4           5    1439     Visual Disturbances                     NaN
# ...       ...     ...                     ...                     ...
# 12482   15670  228575  Incision #5- Treatment  Incision #5- Treatment
# 12483   15671  228576  Incision #6- Treatment  Incision #6- Treatment
# 12484   15672  228577  Impaired Skin #2- Type  Impaired Skin #2- Type
# 12485   15673  228578  Impaired Skin #3- Type  Impaired Skin #3- Type
# 12486   15674  228579  Impaired Skin #4- Type  Impaired Skin #4- Type
#
#          dbsource      linksto           category unitname param_type  \
# ...

# %%
D_ITEMS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12487 entries, 0 to 12486
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   row_id        12487 non-null  int64
#  1   itemid        12487 non-null  int64
#  2   label         12483 non-null  object
#  3   abbreviation  2992 non-null   object
#  4   dbsource      12487 non-null  object
#  5   linksto       12487 non-null  object
#  6   category      6049 non-null   object
#  7   unitname      1234 non-null   object
#  8   param_type    2992 non-null   object
#  9   conceptid     0 non-null      float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 975.7+ KB

# %%
D_ITEMS_names = list(D_ITEMS.columns.values)
D_ITEMS_names
# Out:
# ['row_id',
#  'itemid',
#  'label',
#  'abbreviation',
#  'dbsource',
#  'linksto',
#  'category',
#  'unitname',
#  'param_type',
#  'conceptid']

# %%
D_ITEMS_descripcion = ['identificador de fila','Clasificación de item','Nombre del item ','Abreviacion','Fuente de datos','tabla de donde proviene el item','Categoria','nombre unico del item','tipo de item','Id para relacionar conceptos']

# %%
# Unimos la lista con nombres de columnas y la descripcion de cada columna
D_ITEMS_completo= dict(zip(D_ITEMS_names,D_ITEMS_descripcion))
# Creamos el df
D_ITEMS_columnas = pd.DataFrame([[key, D_ITEMS_completo[key]] for key in D_ITEMS_completo.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
D_ITEMS_dtype = ['int','int','O','O','O','O','O','O','O','int']
# Agregamos el tipo de dato
D_ITEMS_columnas['Dtype'] = D_ITEMS_dtype
# Agregamos nombre de columna
D_ITEMS_columnas['tabla'] = 'D_ITEMS'

# %%
D_ITEMS_columnas
# Out:
#            Name                      Descripcion Dtype    tabla
# 0        row_id            identificador de fila   int  D_ITEMS
# 1        itemid            Clasificación de item   int  D_ITEMS
# 2         label                 Nombre del item      O  D_ITEMS
# 3  abbreviation                      Abreviacion     O  D_ITEMS
# 4      dbsource                  Fuente de datos     O  D_ITEMS
# 5       linksto  tabla de donde proviene el item     O  D_ITEMS
# 6      category                        Categoria     O  D_ITEMS
# 7      unitname            nombre unico del item     O  D_ITEMS
# 8    param_type                     tipo de item     O  D_ITEMS
# 9     conceptid     Id para relacionar conceptos   int  D_ITEMS

# %% [markdown]
# tabla 26

# %%
D_LABITEMS=pd.read_csv(r'https://raw.githubusercontent.com/espadaone/PF_UCI-/main/datasets/D_LABITEMS.csv',sep=",")
D_LABITEMS #Diagnosticos y abreviados
# Out:
#      row_id  itemid                                label             fluid  \
# 0         1   50800                        SPECIMEN TYPE             BLOOD
# 1         2   50801           Alveolar-arterial Gradient             Blood
# 2         3   50802                          Base Excess             Blood
# 3         4   50803  Calculated Bicarbonate, Whole Blood             Blood
# 4         5   50804                 Calculated Total CO2             Blood
# ..      ...     ...                                  ...               ...
# 748     749   51551                      VOIDED SPECIMEN  OTHER BODY FLUID
# 749     750   51552                      VOIDED SPECIMEN             STOOL
# 750     751   51553                      VOIDED SPECIMEN             URINE
# 751     752   51554                      VOIDED SPECIMEN       JOINT FLUID
# 752     753   51555             SURFACTANT ALBUMIN RATIO  OTHER BODY FLUID
#
#        category loinc_code
# 0     BLOOD GAS        NaN
# ...

# %%
D_LABITEMS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   row_id      753 non-null    int64
#  1   itemid      753 non-null    int64
#  2   label       753 non-null    object
#  3   fluid       753 non-null    object
#  4   category    753 non-null    object
#  5   loinc_code  585 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 35.4+ KB

# %%
D_LABITEMS_names = list(D_LABITEMS.columns.values)
D_LABITEMS_names
# Out:
# ['row_id', 'itemid', 'label', 'fluid', 'category', 'loinc_code']

# %%
D_LABITEMS_descripcion = ['identificador de fila','Clasificación de item','Nombre del item ','Tipo de fluido','categoria','Identificador logico por nombre y codigo de item']

# %%
# Unimos la lista con nombres de columnas y la descripcion de cada columna
D_LABITEMS_completo= dict(zip(D_LABITEMS_names,D_LABITEMS_descripcion))
# Creamos el df
D_LABITEMS_columnas = pd.DataFrame([[key, D_LABITEMS_completo[key]] for key in D_LABITEMS_completo.keys()], columns=['Name', 'Descripcion'])
# Tipo de dato de cada columna
D_LABITEMS_dtype = ['int','int','O','O','O','O']
# Agregamos el tipo de dato
D_LABITEMS_columnas['Dtype'] = D_LABITEMS_dtype
# Agregamos nombre de columna
D_LABITEMS_columnas['tabla'] = 'D_ITEMS'

# %%
D_LABITEMS_columnas
# Out:
#          Name                                       Descripcion Dtype    tabla
# 0      row_id                             identificador de fila   int  D_ITEMS
# 1      itemid                             Clasificación de item   int  D_ITEMS
# 2       label                                  Nombre del item      O  D_ITEMS
# 3       fluid                                    Tipo de fluido     O  D_ITEMS
# 4    category                                         categoria     O  D_ITEMS
# 5  loinc_code  Identificador logico por nombre y codigo de item     O  D_ITEMS

# %% [markdown]
# tablas 21 a la 26

# %%
PROCEDURES_ICD_columnas

# %%
D_CPT_columnas

# %%
D_ICD_DIAGNOSES_columnas

# %%
D_ICD_PROCEDURES_columnas

# %%
D_ITEMS_columnas

# %%
D_LABITEMS_columnas

# %%
Union_tablas21_26=pd.concat([PROCEDURES_ICD_columnas,D_CPT_columnas,D_ICD_DIAGNOSES_columnas,D_ICD_PROCEDURES_columnas,D_ITEMS_columnas,D_LABITEMS_columnas])

# %%
Union_tablas21_26
# Out:
#                   Name                                        Descripcion  \
# 0               row_id                              identificador de fila
# 1           subject_id                                     id de paciente
# 2              hadm_id                                     id de admision
# 3              seq_num             numero de procedimiento ocurrido antes
# 4            icd9_code  clasificación para describir enfermedades, les...
# 0               row_id                              identificador de fila
# 1             category                                          categoria
# 2         sectionrange                                Rango de la seccion
# 3        sectionheader                                   seccion cabecera
# 4      subsectionrange                             Rango de la subseccion
# 5     subsectionheader                          cabecera de la subseccion
# 6           codesuffix            Elem. de Texto de terminologia procesal
# ...

# %%
Union_tablas21_26.to_csv('UnionTablas21_26',sep=",")
